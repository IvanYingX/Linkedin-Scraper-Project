# %%
import pandas as pd

output = pd.read_csv("output_data.csv")
output.head(10)
# Out:
#                                                    0  \
# 0           Head of Data Science - National Retailer
# 1                                               Salt
# 2                    London, England, United Kingdom
# 3   £100,000/yr - £140,000/yr · Full-time · Director
# 4  Head of Data Science\nNational Retailer\n· Wor...
# 5  https://www.linkedin.com/jobs/view/2867278998/...
#
#                                                    1  \
# 0                      Senior Manager - Data Science
# 1                                            KPMG UK
# 2                    London, England, United Kingdom
# 3                       Full-time · Mid-Senior level
# 4  The Team\nOur highly specialised Data Science ...
# 5  https://www.linkedin.com/jobs/view/2866335445/...
#
#                                                    2  \
# 0                   Developer Advocate, Data Science
# 1                                              Layer
# ...

# %%
output.transpose()
output
# Out:
#                                                    0  \
# 0           Head of Data Science - National Retailer
# 1                                               Salt
# 2                    London, England, United Kingdom
# 3   £100,000/yr - £140,000/yr · Full-time · Director
# 4  Head of Data Science\nNational Retailer\n· Wor...
# 5  https://www.linkedin.com/jobs/view/2867278998/...
#
#                                                    1  \
# 0                      Senior Manager - Data Science
# 1                                            KPMG UK
# 2                    London, England, United Kingdom
# 3                       Full-time · Mid-Senior level
# 4  The Team\nOur highly specialised Data Science ...
# 5  https://www.linkedin.com/jobs/view/2866335445/...
#
#                                                    2  \
# 0                   Developer Advocate, Data Science
# 1                                              Layer
# ...
