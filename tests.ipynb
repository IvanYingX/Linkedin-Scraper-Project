# %%
import pandas as pd

output = pd.read_csv("output_data.csv")
output.head(10)
# Out:
#                                                    0  \
# 0  Senior Business Intel Engineer, EU Customer Be...
# 1                                             Amazon
# 2                    London, England, United Kingdom
# 3                       Full-time · Mid-Senior level
# 4  Job Summary\n\nDESCRIPTION\n\nAre you passiona...
# 5  https://www.linkedin.com/jobs/view/2877445631/...
#
#                                                    1  \
# 0    Principal Consultant - Data Science - Transport
# 1                                      PA Consulting
# 2                    London, England, United Kingdom
# 3                       Full-time · Mid-Senior level
# 4  Company Description\n\nBringing Ingenuity to L...
# 5  https://www.linkedin.com/jobs/view/2876114098/...
#
#                                                    2  \
# 0                              Director Data Science
# 1                                      MBN Solutions
# ...
